# %% [markdown]
# ## Creating new columns for raw counts and percentages and filling in the missing values

# %%
import pandas as pd

# %%
df = pd.read_excel('cleaned_K13_2_updated.xlsx')

# %%
import pandas as pd
import re

# Ensure string format
df["mutation_frequency(%)"] = df["mutation_frequency(%)"].astype(str)
df["data_extraction_comments"] = df["data_extraction_comments"].astype(str)

def extract_values(row):
    freq = row["mutation_frequency(%)"].strip()
    comment = row["data_extraction_comments"].strip().upper()

    # Case 1: Direct percentage e.g. 4.5
    if "PERCENTAGE" in comment:
        try:
            return pd.Series({
                "raw_count": None,
                "percentage_frequency": float(freq)
            })
        except ValueError:
            return pd.Series({
                "raw_count": None,
                "percentage_frequency": None
            })

    # Case 2: RAW_COUNTS comment
    if "RAW_COUNTS" in comment:
        # If format is x/y, calculate % from it
        if "/" in freq:
            try:
                num, denom = map(float, freq.split("/"))
                percentage = round((num / denom) * 100, 2) if denom else None
                return pd.Series({
                    "raw_count": freq,
                    "percentage_frequency": percentage
                })
            except:
                return pd.Series({
                    "raw_count": freq,
                    "percentage_frequency": None
                })
        else:
            return pd.Series({
                "raw_count": freq,
                "percentage_frequency": None
            })

    # Case 3: mixed format like 90/195 (46.4)
    match = re.match(r"(\d+/\d+)\s*\(([\d\.]+)\)", freq)
    if match:
        raw = match.group(1)
        percentage = float(match.group(2))
        return pd.Series({
            "raw_count": raw,
            "percentage_frequency": percentage
        })

    # Fallback: Try to calculate from x/y
    if "/" in freq:
        try:
            num, denom = map(float, freq.split("/"))
            percentage = round((num / denom) * 100, 2) if denom else None
            return pd.Series({
                "raw_count": freq,
                "percentage_frequency": percentage
            })
        except:
            return pd.Series({
                "raw_count": freq,
                "percentage_frequency": None
            })

    # If everything fails
    return pd.Series({
        "raw_count": None,
        "percentage_frequency": None
    })

# Apply it
df[["raw_count", "percentage_frequency"]] = df.apply(extract_values, axis=1)

# %%
df.head(20)
# Out:
#          pmid  year_pub year_sample     country  \
# 0    34551228      2021   2015-2019      UGANDA
# 1    34551228      2021   2015-2029      UGANDA
# 2    35703955      2022     missing         DRC
# 3    36036611      2022   2016-2017       KENYA
# 4    39136468      2024   2015-2023      UGANDA
# 5    39136468      2024   2015-2023      UGANDA
# 6    34641867      2021        2018  MOZAMBIQUE
# 7    26483118      2015   2013-2014    ETHIOPIA
# 8    26483118      2015   2013-2014    ETHIOPIA
# 9    26483118      2015   2013-2014    ETHIOPIA
# 10   26483118      2015   2013-2014    ETHIOPIA
# 11   26483118      2015   2013-2014    ETHIOPIA
# 12   36451216      2022        2017    ETHIOPIA
# 13   36451216      2022        2017    ETHIOPIA
# 14   29718283      2018   2013-2014         DRC
# 15   39159629      2024        2021    TANZANIA
# 16   39159629      2024        2021    TANZANIA
# 17   39159629      2024        2021    TANZANIA
# 18   39159629      2024        2021    TANZANIA
# 19   39159629      2024        2021    TANZANIA
#
#                                       region/province  \
# 0                                     NORTHERN UGANDA
# 1                                     NORTHERN UGANDA
# 2                                         CENTRAL DRC
# 3                                       WESTERN KENYA
# 4                                      EASTERN UGANDA
# 5                                      EASTERN UGANDA
# 6    CABO DELGADO, TETE, ZAMBÉZIA, INHAMBANE PROVINCE
# 7                    (AMHARA REGIONAL STATE)NORTHWEST
# 8                    (AMHARA REGIONAL STATE)NORTHWEST
# 9                    (AMHARA REGIONAL STATE)NORTHWEST
# 10                   (AMHARA REGIONAL STATE)NORTHWEST
# 11                   (AMHARA REGIONAL STATE)NORTHWEST
# 12                                  BENISHANGUL GUMUZ
# 13  SOUTHERN NATIONS AND NATIONALITIES PEOPLES' (S...
# 14                                            MISSING
# 15                                      DAR ES SALAAM
# 16                                      DAR ES SALAAM
# 17                                      DAR ES SALAAM
# 18                                             DODOMA
# 19                                             DODOMA
#
#                                     town participants_age  \
# 0                                   GULU             ≥0.5
# 1                                   GULU             ≥0.5
# 2                              KINSHASHA           03-Jun
# 3                                  SIAYA               <5
# 4                   TORORO, BUSIA, MBALE             >0.5
# 5                   TORORO, BUSIA, MBALE             >0.5
# 6   MONTEPUEZ, MOATIZE, MOPEIA, MASSINGA         0.5 -  5
# 7                            ADDIS ZEMEN           Jan-69
# 8                                  AYKEL           Jan-69
# 9                              MAKSEGNET           Jan-69
# 10                          NEGADE BAHIR           Jan-69
# 11                                 SANJA           Jan-69
# 12                                  PAWE             >0.5
# 13                             GAMU-GOFA             >0.5
# 14                               MISSING          missing
# 15                               MISSING             >0.5
# 16                               MISSING             >0.5
# 17                               MISSING             >0.5
# 18                               MISSING             >0.5
# 19                               MISSING             >0.5
#
#    participants_age_unit sample_size first_line_ACT  ... type_of_mutation  \
# 0                  YEARS         274             AL  ...   NON-SYNONYMOUS
# 1                  YEARS         274             AL  ...   NON-SYNONYMOUS
# 2                  YEARS         118           ASAQ  ...          MISSING
# 3                  YEARS         340             AL  ...          MISSING
# 4                  YEARS        1112             AL  ...   NON-SYNONYMOUS
# 5                  YEARS        1112             AL  ...   NON-SYNONYMOUS
# 6                  YEARS         641       AL, ASAQ  ...              NaN
# 7                  YEARS          31             AL  ...          MISSING
# 8                  YEARS          15             AL  ...   NON-SYNONYMOUS
# 9                  YEARS          49             AL  ...          MISSING
# 10                 YEARS          31             AL  ...   NON-SYNONYMOUS
# 11                 YEARS          22             AL  ...          MISSING
# 12                 YEARS         379             AL  ...          MISSING
# 13                 YEARS         379             AL  ...          MISSING
# 14               MISSING        1622           ASAQ  ...          MISSING
# 15                 YEARS         570             AL  ...   NON-SYNONYMOUS
# 16                 YEARS         570             AL  ...   NON-SYNONYMOUS
# 17                 YEARS         570             AL  ...   NON-SYNONYMOUS
# 18                 YEARS         594             AL  ...   NON-SYNONYMOUS
# 19                 YEARS         594             AL  ...   NON-SYNONYMOUS
#
#    mutation_frequency(%)                where_sequenced   other_k13_mutations  \
# 0                     27                        MISSING                     -
# 1                      5                        MISSING                     -
# 2                      0                        MISSING   A578S, Q613E, S522C
# 3                      0                        MISSING                     -
# 4                      4                        MISSING                 A578S
# 5                      3                        MISSING                     -
# 6                      0                   CDC, ATLANTA  TGC469TGT, GGC548GGT
# 7                      0  UNIVERSITY OF CALGARY, CANADA                     -
# 8                 1(6.7)  UNIVERSITY OF CALGARY, CANADA                     -
# 9                      0  UNIVERSITY OF CALGARY, CANADA                     -
# 10               2(11.1)  UNIVERSITY OF CALGARY, CANADA                     -
# 11                     0  UNIVERSITY OF CALGARY, CANADA                     -
# 12                     0                   CDC, ATLANTA                 E433D
# 13                     0                   CDC, ATLANTA                     -
# 14                     0    UNIVERSITY OF MASSACHUSSETS                     -
# 15                     0   UNIVERSITY OF NORTH CAROLINA          R255K, L258M
# 16                     0   UNIVERSITY OF NORTH CAROLINA                   NaN
# 17                     0   UNIVERSITY OF NORTH CAROLINA                   NaN
# 18                     0   UNIVERSITY OF NORTH CAROLINA   R255K, L258M, K189T
# 19                     0   UNIVERSITY OF NORTH CAROLINA                   NaN
#
#    data_extraction_comments journal_access Latitude Longitude raw_count  \
# 0                RAW_COUNTS           OPEN   1.3730    32.290        27
# 1                RAW_COUNTS           OPEN   1.3730    32.290         5
# 2                RAW_COUNTS           OPEN   4.0380    21.759         0
# 3                RAW_COUNTS           OPEN   0.0234    37.906         0
# 4                RAW_COUNTS           OPEN   1.3730    32.290         4
# 5                RAW_COUNTS           OPEN   1.3730    32.290         3
# 6                RAW_COUNTS           OPEN  18.6660    35.529         0
# 7                RAW_COUNTS           OPEN   9.1450    40.489         0
# 8                RAW_COUNTS           OPEN   9.1450    40.489    1(6.7)
# 9                RAW_COUNTS           OPEN   9.1450    40.489         0
# 10               RAW_COUNTS           OPEN   9.1450    40.489   2(11.1)
# 11               RAW_COUNTS           OPEN   9.1450    40.489         0
# 12               RAW_COUNTS           OPEN   9.1450    40.489         0
# 13               RAW_COUNTS           OPEN   9.1450    40.489         0
# 14               RAW_COUNTS           OPEN   4.0380    21.759         0
# 15               RAW_COUNTS           OPEN   6.3690    34.889         0
# 16               RAW_COUNTS           OPEN   6.3690    34.889         0
# 17               RAW_COUNTS           OPEN   6.3690    34.889         0
# 18               RAW_COUNTS           OPEN   6.3690    34.889         0
# 19               RAW_COUNTS           OPEN   6.3690    34.889         0
#
#    percentage_frequency
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
#
# [20 rows x 24 columns]

# %%
import pandas as pd
import numpy as np

# Make sure raw_count and percentage_frequency columns exist and are strings
df["raw_count"] = df["raw_count"].astype(str)
df["percentage_frequency"] = df.get("percentage_frequency", pd.Series(np.nan, index=df.index))

# Only update where percentage_frequency is missing
mask_missing = df["percentage_frequency"].isna()

# Extract percentage from raw_count where it's missing
extracted_pct = df.loc[mask_missing, "raw_count"].str.extract(r"\(([\d\.]+)\)")
df.loc[mask_missing, "percentage_frequency"] = pd.to_numeric(extracted_pct[0], errors="coerce")

# Strip the bracketed part from raw_count to keep only the main value
df["raw_count"] = df["raw_count"].str.replace(r"\s*\(.*?\)", "", regex=True).str.strip()

# %%
df.head(20)
# Out:
#          pmid  year_pub year_sample     country  \
# 0    34551228      2021   2015-2019      UGANDA
# 1    34551228      2021   2015-2029      UGANDA
# 2    35703955      2022     missing         DRC
# 3    36036611      2022   2016-2017       KENYA
# 4    39136468      2024   2015-2023      UGANDA
# 5    39136468      2024   2015-2023      UGANDA
# 6    34641867      2021        2018  MOZAMBIQUE
# 7    26483118      2015   2013-2014    ETHIOPIA
# 8    26483118      2015   2013-2014    ETHIOPIA
# 9    26483118      2015   2013-2014    ETHIOPIA
# 10   26483118      2015   2013-2014    ETHIOPIA
# 11   26483118      2015   2013-2014    ETHIOPIA
# 12   36451216      2022        2017    ETHIOPIA
# 13   36451216      2022        2017    ETHIOPIA
# 14   29718283      2018   2013-2014         DRC
# 15   39159629      2024        2021    TANZANIA
# 16   39159629      2024        2021    TANZANIA
# 17   39159629      2024        2021    TANZANIA
# 18   39159629      2024        2021    TANZANIA
# 19   39159629      2024        2021    TANZANIA
#
#                                       region/province  \
# 0                                     NORTHERN UGANDA
# 1                                     NORTHERN UGANDA
# 2                                         CENTRAL DRC
# 3                                       WESTERN KENYA
# 4                                      EASTERN UGANDA
# 5                                      EASTERN UGANDA
# 6    CABO DELGADO, TETE, ZAMBÉZIA, INHAMBANE PROVINCE
# 7                    (AMHARA REGIONAL STATE)NORTHWEST
# 8                    (AMHARA REGIONAL STATE)NORTHWEST
# 9                    (AMHARA REGIONAL STATE)NORTHWEST
# 10                   (AMHARA REGIONAL STATE)NORTHWEST
# 11                   (AMHARA REGIONAL STATE)NORTHWEST
# 12                                  BENISHANGUL GUMUZ
# 13  SOUTHERN NATIONS AND NATIONALITIES PEOPLES' (S...
# 14                                            MISSING
# 15                                      DAR ES SALAAM
# 16                                      DAR ES SALAAM
# 17                                      DAR ES SALAAM
# 18                                             DODOMA
# 19                                             DODOMA
#
#                                     town participants_age  \
# 0                                   GULU             ≥0.5
# 1                                   GULU             ≥0.5
# 2                              KINSHASHA           03-Jun
# 3                                  SIAYA               <5
# 4                   TORORO, BUSIA, MBALE             >0.5
# 5                   TORORO, BUSIA, MBALE             >0.5
# 6   MONTEPUEZ, MOATIZE, MOPEIA, MASSINGA         0.5 -  5
# 7                            ADDIS ZEMEN           Jan-69
# 8                                  AYKEL           Jan-69
# 9                              MAKSEGNET           Jan-69
# 10                          NEGADE BAHIR           Jan-69
# 11                                 SANJA           Jan-69
# 12                                  PAWE             >0.5
# 13                             GAMU-GOFA             >0.5
# 14                               MISSING          missing
# 15                               MISSING             >0.5
# 16                               MISSING             >0.5
# 17                               MISSING             >0.5
# 18                               MISSING             >0.5
# 19                               MISSING             >0.5
#
#    participants_age_unit sample_size first_line_ACT  ... type_of_mutation  \
# 0                  YEARS         274             AL  ...   NON-SYNONYMOUS
# 1                  YEARS         274             AL  ...   NON-SYNONYMOUS
# 2                  YEARS         118           ASAQ  ...          MISSING
# 3                  YEARS         340             AL  ...          MISSING
# 4                  YEARS        1112             AL  ...   NON-SYNONYMOUS
# 5                  YEARS        1112             AL  ...   NON-SYNONYMOUS
# 6                  YEARS         641       AL, ASAQ  ...              NaN
# 7                  YEARS          31             AL  ...          MISSING
# 8                  YEARS          15             AL  ...   NON-SYNONYMOUS
# 9                  YEARS          49             AL  ...          MISSING
# 10                 YEARS          31             AL  ...   NON-SYNONYMOUS
# 11                 YEARS          22             AL  ...          MISSING
# 12                 YEARS         379             AL  ...          MISSING
# 13                 YEARS         379             AL  ...          MISSING
# 14               MISSING        1622           ASAQ  ...          MISSING
# 15                 YEARS         570             AL  ...   NON-SYNONYMOUS
# 16                 YEARS         570             AL  ...   NON-SYNONYMOUS
# 17                 YEARS         570             AL  ...   NON-SYNONYMOUS
# 18                 YEARS         594             AL  ...   NON-SYNONYMOUS
# 19                 YEARS         594             AL  ...   NON-SYNONYMOUS
#
#    mutation_frequency(%)                where_sequenced   other_k13_mutations  \
# 0                     27                        MISSING                     -
# 1                      5                        MISSING                     -
# 2                      0                        MISSING   A578S, Q613E, S522C
# 3                      0                        MISSING                     -
# 4                      4                        MISSING                 A578S
# 5                      3                        MISSING                     -
# 6                      0                   CDC, ATLANTA  TGC469TGT, GGC548GGT
# 7                      0  UNIVERSITY OF CALGARY, CANADA                     -
# 8                 1(6.7)  UNIVERSITY OF CALGARY, CANADA                     -
# 9                      0  UNIVERSITY OF CALGARY, CANADA                     -
# 10               2(11.1)  UNIVERSITY OF CALGARY, CANADA                     -
# 11                     0  UNIVERSITY OF CALGARY, CANADA                     -
# 12                     0                   CDC, ATLANTA                 E433D
# 13                     0                   CDC, ATLANTA                     -
# 14                     0    UNIVERSITY OF MASSACHUSSETS                     -
# 15                     0   UNIVERSITY OF NORTH CAROLINA          R255K, L258M
# 16                     0   UNIVERSITY OF NORTH CAROLINA                   NaN
# 17                     0   UNIVERSITY OF NORTH CAROLINA                   NaN
# 18                     0   UNIVERSITY OF NORTH CAROLINA   R255K, L258M, K189T
# 19                     0   UNIVERSITY OF NORTH CAROLINA                   NaN
#
#    data_extraction_comments journal_access Latitude Longitude raw_count  \
# 0                RAW_COUNTS           OPEN   1.3730    32.290        27
# 1                RAW_COUNTS           OPEN   1.3730    32.290         5
# 2                RAW_COUNTS           OPEN   4.0380    21.759         0
# 3                RAW_COUNTS           OPEN   0.0234    37.906         0
# 4                RAW_COUNTS           OPEN   1.3730    32.290         4
# 5                RAW_COUNTS           OPEN   1.3730    32.290         3
# 6                RAW_COUNTS           OPEN  18.6660    35.529         0
# 7                RAW_COUNTS           OPEN   9.1450    40.489         0
# 8                RAW_COUNTS           OPEN   9.1450    40.489         1
# 9                RAW_COUNTS           OPEN   9.1450    40.489         0
# 10               RAW_COUNTS           OPEN   9.1450    40.489         2
# 11               RAW_COUNTS           OPEN   9.1450    40.489         0
# 12               RAW_COUNTS           OPEN   9.1450    40.489         0
# 13               RAW_COUNTS           OPEN   9.1450    40.489         0
# 14               RAW_COUNTS           OPEN   4.0380    21.759         0
# 15               RAW_COUNTS           OPEN   6.3690    34.889         0
# 16               RAW_COUNTS           OPEN   6.3690    34.889         0
# 17               RAW_COUNTS           OPEN   6.3690    34.889         0
# 18               RAW_COUNTS           OPEN   6.3690    34.889         0
# 19               RAW_COUNTS           OPEN   6.3690    34.889         0
#
#    percentage_frequency
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   6.7
# 9                   NaN
# 10                 11.1
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
#
# [20 rows x 24 columns]

# %%
df
# Out:
#           pmid  year_pub year_sample country  region/province  \
# 0     34551228      2021   2015-2019  UGANDA  NORTHERN UGANDA
# 1     34551228      2021   2015-2029  UGANDA  NORTHERN UGANDA
# 2     35703955      2022     missing     DRC      CENTRAL DRC
# 3     36036611      2022   2016-2017   KENYA    WESTERN KENYA
# 4     39136468      2024   2015-2023  UGANDA   EASTERN UGANDA
# ..         ...       ...         ...     ...              ...
# 660   37611122      2023        2022  UGANDA           RUKIGA
# 661   37611122      2023        2022  UGANDA           RUKIGA
# 662   37611122      2023        2022  UGANDA           TORORO
# 663   37611122      2023        2022  UGANDA           TORORO
# 664   37611122      2023        2022  UGANDA           TORORO
#
#                      town participants_age participants_age_unit sample_size  \
# 0                    GULU             ≥0.5                 YEARS         274
# 1                    GULU             ≥0.5                 YEARS         274
# 2               KINSHASHA           03-Jun                 YEARS         118
# 3                   SIAYA               <5                 YEARS         340
# 4    TORORO, BUSIA, MBALE             >0.5                 YEARS        1112
# ..                    ...              ...                   ...         ...
# 660                RUKIGA          missing                     -         100
# 661                RUKIGA          missing                     -         100
# 662                TORORO          missing                     -         100
# 663                TORORO          missing                     -         100
# 664                TORORO          missing                     -         100
#
#     first_line_ACT  ... type_of_mutation mutation_frequency(%)  \
# 0               AL  ...   NON-SYNONYMOUS                    27
# 1               AL  ...   NON-SYNONYMOUS                     5
# 2             ASAQ  ...          MISSING                     0
# 3               AL  ...          MISSING                     0
# 4               AL  ...   NON-SYNONYMOUS                     4
# ..             ...  ...              ...                   ...
# 660             AL  ...   NON-SYNONYMOUS                   5.1
# 661             AL  ...   NON-SYNONYMOUS                  22.6
# 662             AL  ...   NON-SYNONYMOUS                   9.8
# 663             AL  ...   NON-SYNONYMOUS                  15.8
# 664             AL  ...   NON-SYNONYMOUS                     0
#
#     where_sequenced  other_k13_mutations data_extraction_comments  \
# 0           MISSING                    -               RAW_COUNTS
# 1           MISSING                    -               RAW_COUNTS
# 2           MISSING  A578S, Q613E, S522C               RAW_COUNTS
# 3           MISSING                    -               RAW_COUNTS
# 4           MISSING                A578S               RAW_COUNTS
# ..              ...                  ...                      ...
# 660         MISSING                    -               PERCENTAGE
# 661         MISSING                    -               PERCENTAGE
# 662         MISSING                    -               PERCENTAGE
# 663         MISSING                    -               PERCENTAGE
# 664         MISSING                    -               PERCENTAGE
#
#     journal_access Latitude Longitude raw_count percentage_frequency
# 0             OPEN   1.3730    32.290        27                  NaN
# 1             OPEN   1.3730    32.290         5                  NaN
# 2             OPEN   4.0380    21.759         0                  NaN
# 3             OPEN   0.0234    37.906         0                  NaN
# 4             OPEN   1.3730    32.290         4                  NaN
# ..             ...      ...       ...       ...                  ...
# 660           OPEN   1.3730    32.290       NaN                  5.1
# 661           OPEN   1.3730    32.290       NaN                 22.6
# 662           OPEN   1.3730    32.290       NaN                  9.8
# 663           OPEN   1.3730    32.290       NaN                 15.8
# 664           OPEN   1.3730    32.290       NaN                  0.0
#
# [665 rows x 24 columns]

# %%
# Set percentage to 0 where mutation_frequency is '0'
df.loc[df["mutation_frequency(%)"].str.strip() == "0", "percentage_frequency"] = 0.0

# %%
df
# Out:
#           pmid  year_pub year_sample country  region/province  \
# 0     34551228      2021   2015-2019  UGANDA  NORTHERN UGANDA
# 1     34551228      2021   2015-2029  UGANDA  NORTHERN UGANDA
# 2     35703955      2022     missing     DRC      CENTRAL DRC
# 3     36036611      2022   2016-2017   KENYA    WESTERN KENYA
# 4     39136468      2024   2015-2023  UGANDA   EASTERN UGANDA
# ..         ...       ...         ...     ...              ...
# 660   37611122      2023        2022  UGANDA           RUKIGA
# 661   37611122      2023        2022  UGANDA           RUKIGA
# 662   37611122      2023        2022  UGANDA           TORORO
# 663   37611122      2023        2022  UGANDA           TORORO
# 664   37611122      2023        2022  UGANDA           TORORO
#
#                      town participants_age participants_age_unit sample_size  \
# 0                    GULU             ≥0.5                 YEARS         274
# 1                    GULU             ≥0.5                 YEARS         274
# 2               KINSHASHA           03-Jun                 YEARS         118
# 3                   SIAYA               <5                 YEARS         340
# 4    TORORO, BUSIA, MBALE             >0.5                 YEARS        1112
# ..                    ...              ...                   ...         ...
# 660                RUKIGA          missing                     -         100
# 661                RUKIGA          missing                     -         100
# 662                TORORO          missing                     -         100
# 663                TORORO          missing                     -         100
# 664                TORORO          missing                     -         100
#
#     first_line_ACT  ... type_of_mutation mutation_frequency(%)  \
# 0               AL  ...   NON-SYNONYMOUS                    27
# 1               AL  ...   NON-SYNONYMOUS                     5
# 2             ASAQ  ...          MISSING                     0
# 3               AL  ...          MISSING                     0
# 4               AL  ...   NON-SYNONYMOUS                     4
# ..             ...  ...              ...                   ...
# 660             AL  ...   NON-SYNONYMOUS                   5.1
# 661             AL  ...   NON-SYNONYMOUS                  22.6
# 662             AL  ...   NON-SYNONYMOUS                   9.8
# 663             AL  ...   NON-SYNONYMOUS                  15.8
# 664             AL  ...   NON-SYNONYMOUS                     0
#
#     where_sequenced  other_k13_mutations data_extraction_comments  \
# 0           MISSING                    -               RAW_COUNTS
# 1           MISSING                    -               RAW_COUNTS
# 2           MISSING  A578S, Q613E, S522C               RAW_COUNTS
# 3           MISSING                    -               RAW_COUNTS
# 4           MISSING                A578S               RAW_COUNTS
# ..              ...                  ...                      ...
# 660         MISSING                    -               PERCENTAGE
# 661         MISSING                    -               PERCENTAGE
# 662         MISSING                    -               PERCENTAGE
# 663         MISSING                    -               PERCENTAGE
# 664         MISSING                    -               PERCENTAGE
#
#     journal_access Latitude Longitude raw_count percentage_frequency
# 0             OPEN   1.3730    32.290        27                  NaN
# 1             OPEN   1.3730    32.290         5                  NaN
# 2             OPEN   4.0380    21.759         0                  0.0
# 3             OPEN   0.0234    37.906         0                  0.0
# 4             OPEN   1.3730    32.290         4                  NaN
# ..             ...      ...       ...       ...                  ...
# 660           OPEN   1.3730    32.290       NaN                  5.1
# 661           OPEN   1.3730    32.290       NaN                 22.6
# 662           OPEN   1.3730    32.290       NaN                  9.8
# 663           OPEN   1.3730    32.290       NaN                 15.8
# 664           OPEN   1.3730    32.290       NaN                  0.0
#
# [665 rows x 24 columns]

# %%
# Set raw_count to 0 where percentage_frequency is 0
df.loc[df["percentage_frequency"] == 0, "raw_count"] = 0

# %%
df.to_excel("cleaned_k13_2_stripped.xlsx", index=False)

# %%
df=pd.read_excel("cleaned_k13_2_stripped.xlsx")

# %%
df
# Out:
#           pmid  year_pub year_sample country  region/province  \
# 0     34551228      2021   2015-2019  UGANDA  NORTHERN UGANDA
# 1     34551228      2021   2015-2029  UGANDA  NORTHERN UGANDA
# 2     35703955      2022     missing     DRC      CENTRAL DRC
# 3     36036611      2022   2016-2017   KENYA    WESTERN KENYA
# 4     39136468      2024   2015-2023  UGANDA   EASTERN UGANDA
# ..         ...       ...         ...     ...              ...
# 660   37611122      2023        2022  UGANDA           RUKIGA
# 661   37611122      2023        2022  UGANDA           RUKIGA
# 662   37611122      2023        2022  UGANDA           TORORO
# 663   37611122      2023        2022  UGANDA           TORORO
# 664   37611122      2023        2022  UGANDA           TORORO
#
#                      town participants_age participants_age_unit sample_size  \
# 0                    GULU             ≥0.5                 YEARS         274
# 1                    GULU             ≥0.5                 YEARS         274
# 2               KINSHASHA           03-Jun                 YEARS         118
# 3                   SIAYA               <5                 YEARS         340
# 4    TORORO, BUSIA, MBALE             >0.5                 YEARS        1112
# ..                    ...              ...                   ...         ...
# 660                RUKIGA          missing                     -         100
# 661                RUKIGA          missing                     -         100
# 662                TORORO          missing                     -         100
# 663                TORORO          missing                     -         100
# 664                TORORO          missing                     -         100
#
#     first_line_ACT  ... type_of_mutation mutation_frequency(%)  \
# 0               AL  ...   NON-SYNONYMOUS                    27
# 1               AL  ...   NON-SYNONYMOUS                     5
# 2             ASAQ  ...          MISSING                     0
# 3               AL  ...          MISSING                     0
# 4               AL  ...   NON-SYNONYMOUS                     4
# ..             ...  ...              ...                   ...
# 660             AL  ...   NON-SYNONYMOUS                   5.1
# 661             AL  ...   NON-SYNONYMOUS                  22.6
# 662             AL  ...   NON-SYNONYMOUS                   9.8
# 663             AL  ...   NON-SYNONYMOUS                  15.8
# 664             AL  ...   NON-SYNONYMOUS                     0
#
#     where_sequenced  other_k13_mutations data_extraction_comments  \
# 0           MISSING                    -               RAW_COUNTS
# 1           MISSING                    -               RAW_COUNTS
# 2           MISSING  A578S, Q613E, S522C               RAW_COUNTS
# 3           MISSING                    -               RAW_COUNTS
# 4           MISSING                A578S               RAW_COUNTS
# ..              ...                  ...                      ...
# 660         MISSING                    -               PERCENTAGE
# 661         MISSING                    -               PERCENTAGE
# 662         MISSING                    -               PERCENTAGE
# 663         MISSING                    -               PERCENTAGE
# 664         MISSING                    -               PERCENTAGE
#
#     journal_access Latitude Longitude raw_count percentage_frequency
# 0             OPEN   1.3730    32.290        27                  NaN
# 1             OPEN   1.3730    32.290         5                  NaN
# 2             OPEN   4.0380    21.759         0                  0.0
# 3             OPEN   0.0234    37.906         0                  0.0
# 4             OPEN   1.3730    32.290         4                  NaN
# ..             ...      ...       ...       ...                  ...
# 660           OPEN   1.3730    32.290       NaN                  5.1
# 661           OPEN   1.3730    32.290       NaN                 22.6
# 662           OPEN   1.3730    32.290       NaN                  9.8
# 663           OPEN   1.3730    32.290       NaN                 15.8
# 664           OPEN   1.3730    32.290         0                  0.0
#
# [665 rows x 24 columns]

# %%
import pandas as pd
import numpy as np

# Load your data here (example):
# df = pd.read_csv("your_file.csv")

# Step 1: Clean column names
df.columns = df.columns.str.strip().str.lower()

# Step 2: Replace empty strings with NaN in the three relevant columns
for col in ['raw_count', 'percentage_frequency', 'samples_genotyped']:
    df[col] = df[col].replace('', np.nan)

# Step 3: Convert to numeric (in case strings or mixed types exist)
df['raw_count'] = pd.to_numeric(df['raw_count'], errors='coerce')
df['percentage_frequency'] = pd.to_numeric(df['percentage_frequency'], errors='coerce')
df['samples_genotyped'] = pd.to_numeric(df['samples_genotyped'], errors='coerce')

# Step 4: Calculate missing percentage freq
mask_freq_missing = df['percentage_frequency'].isna() & df['raw_count'].notna() & df['samples_genotyped'].notna()
df.loc[mask_freq_missing, 'percentage_frequency'] = (
    df.loc[mask_freq_missing, 'raw_count'] / df.loc[mask_freq_missing, 'samples_genotyped']
) * 100

# Step 5: Calculate missing raw counts
mask_raw_missing = df['raw_count'].isna() & df['percentage_frequency'].notna() & df['samples_genotyped'].notna()
df.loc[mask_raw_missing, 'raw_count'] = round(
    (df.loc[mask_raw_missing, 'percentage_frequency'] / 100) * df.loc[mask_raw_missing, 'samples_genotyped']
)

# Optional: round percentage freq and convert raw counts to Int (nullable)
df['percentage_frequency'] = df['percentage_frequency'].round(2)
df['raw_count'] = df['raw_count'].astype('Int64')  # allows NA

# ✅ Done!
print(df.head())
# Out:
#         pmid  year_pub year_sample country  region/province  \
# 0   34551228      2021   2015-2019  UGANDA  NORTHERN UGANDA
# 1   34551228      2021   2015-2029  UGANDA  NORTHERN UGANDA
# 2   35703955      2022     missing     DRC      CENTRAL DRC
# 3   36036611      2022   2016-2017   KENYA    WESTERN KENYA
# 4   39136468      2024   2015-2023  UGANDA   EASTERN UGANDA
#
#                    town participants_age participants_age_unit sample_size  \
# 0                  GULU             ≥0.5                 YEARS         274
# 1                  GULU             ≥0.5                 YEARS         274
# 2             KINSHASHA           03-Jun                 YEARS         118
# 3                 SIAYA               <5                 YEARS         340
# 4  TORORO, BUSIA, MBALE             >0.5                 YEARS        1112
#
#   first_line_act  ... type_of_mutation mutation_frequency(%)  where_sequenced  \
# 0             AL  ...   NON-SYNONYMOUS                    27          MISSING
# 1             AL  ...   NON-SYNONYMOUS                     5          MISSING
# 2           ASAQ  ...          MISSING                     0          MISSING
# 3             AL  ...          MISSING                     0          MISSING
# 4             AL  ...   NON-SYNONYMOUS                     4          MISSING
#
#    other_k13_mutations data_extraction_comments journal_access latitude  \
# 0                    -               RAW_COUNTS           OPEN   1.3730
# 1                    -               RAW_COUNTS           OPEN   1.3730
# 2  A578S, Q613E, S522C               RAW_COUNTS           OPEN   4.0380
# 3                    -               RAW_COUNTS           OPEN   0.0234
# 4                A578S               RAW_COUNTS           OPEN   1.3730
#
#   longitude raw_count percentage_frequency
# 0    32.290        27                11.25
# 1    32.290         5                 2.08
# 2    21.759         0                 0.00
# 3    37.906         0                 0.00
# 4    32.290         4                 0.36
#
# [5 rows x 24 columns]

# %%
df.to_excel("cleaned_k13_2_latest.xlsx", index=False)

# %%
print("Rows eligible to calculate raw_count:")
print(df[mask_raw_missing][['percentage_frequency', 'samples_genotyped']])
# Out:
# Rows eligible to calculate raw_count:
#      percentage_frequency  samples_genotyped
# 160                  4.55               66.0
# 161                  1.52               66.0
# 164                  0.02               66.0
# 165                  0.02               66.0
# 167                  0.24              422.0
# ..                    ...                ...
# 659                  2.20               46.0
# 660                  5.10               59.0
# 661                 22.60               53.0
# 662                  9.80               51.0
# 663                 15.80               57.0
#
# [148 rows x 2 columns]

# %%
# Step 5: Calculate missing raw counts
mask_raw_missing = df['raw_count'].isna() & df['percentage_frequency'].notna() & df['samples_genotyped'].notna()

print(f"Rows with missing raw_count and available percentage_frequency + samples_genotyped: {mask_raw_missing.sum()}")

if mask_raw_missing.sum() > 0:
    df.loc[mask_raw_missing, 'raw_count'] = round(
        (df.loc[mask_raw_missing, 'percentage_frequency'] / 100) * df.loc[mask_raw_missing, 'samples_genotyped']
    )
else:
    print("No rows found where raw_count can be calculated.")
# Out:
# Rows with missing raw_count and available percentage_frequency + samples_genotyped: 0
# No rows found where raw_count can be calculated.
